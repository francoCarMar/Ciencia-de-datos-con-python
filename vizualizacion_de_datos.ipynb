# %%
# Load data
import pandas as pd
nombres = ['preg', 'plas', 'pres','skin','test','mass','pedi','age','class']
data = pd.read_csv('data/pima-indians-diabetes.csv', names = nombres)
data
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %% [markdown]
# # Histogramas

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (10, 10))
ax = fig.gca()
data.hist(ax = ax)
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_19260\2022720758.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data.hist(ax = ax)
# array([[<Axes: title={'center': 'preg'}>,
#         <Axes: title={'center': 'plas'}>,
#         <Axes: title={'center': 'pres'}>],
#        [<Axes: title={'center': 'skin'}>,
#         <Axes: title={'center': 'test'}>,
#         <Axes: title={'center': 'mass'}>],
#        [<Axes: title={'center': 'pedi'}>,
#         <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'class'}>]], dtype=object)

# %%
# %matplotlib inline
# Univariate Histograms
import matplotlib.pyplot as plt
import seaborn as sns
f, axes = plt.subplots(3, 3, figsize = (14,14))
sns.histplot(data['preg'], ax=axes[0,0])
sns.histplot(data['plas'], ax=axes[0,1])
sns.histplot(data['pres'], ax=axes[0,2])
sns.histplot(data['skin'], ax=axes[1,0])
sns.histplot(data['test'], ax=axes[1,1])
sns.histplot(data['mass'], ax=axes[1,2])
sns.histplot(data['pedi'], ax=axes[2,0])
sns.histplot(data['age'], ax=axes[2,1])
sns.histplot(data['class'], ax=axes[2,2])
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (16, 16))
ax = fig.gca()
data.plot(ax = ax, kind = 'density', subplots = True, layout = (3, 3), sharex = False)
plt.show()
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_19260\2333360601.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data.plot(ax = ax, kind = 'density', subplots = True, layout = (3, 3), sharex = False)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
f, axes = plt.subplots(3, 3, figsize = (14,14))
sns.kdeplot(data['preg'], ax=axes[0,0])
sns.kdeplot(data['plas'], ax=axes[0,1])
sns.kdeplot(data['pres'], ax=axes[0,2])
sns.kdeplot(data['skin'], ax=axes[1,0])
sns.kdeplot(data['test'], ax=axes[1,1])
sns.kdeplot(data['mass'], ax=axes[1,2])
sns.kdeplot(data['pedi'], ax=axes[2,0])
sns.kdeplot(data['age'], ax=axes[2,1])
sns.kdeplot(data['class'], ax=axes[2,2])
plt.show()

# %%
# Box plots 
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (16, 16))
ax = fig.gca()
data.plot(ax = ax, kind = 'box', subplots = True, layout = (3, 3), sharex = False, sharey = False)
plt.show()
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_19260\635894851.py:6: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data.plot(ax = ax, kind = 'box', subplots = True, layout = (3, 3), sharex = False, sharey = False)

# %%
# Con seaborn
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
f, axes = plt.subplots(3, 3, figsize = (14,14))
sns.boxplot(y=data['preg'], ax=axes[0,0])
sns.boxplot(y=data['plas'], ax=axes[0,1])
sns.boxplot(y=data['pres'], ax=axes[0,2])
sns.boxplot(y=data['skin'], ax=axes[1,0])
sns.boxplot(y=data['test'], ax=axes[1,1])
sns.boxplot(y=data['mass'], ax=axes[1,2])
sns.boxplot(y=data['pedi'], ax=axes[2,0])
sns.boxplot(y=data['age'], ax=axes[2,1])
sns.boxplot(y=data['class'], ax=axes[2,2])
plt.show()

# %% [markdown]
# # Matriz de correlación

# %%
# %matplotlib inline
import numpy as np
correlations = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin = -1, vmax = 1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_xticklabels(nombres)
ax.set_yticklabels(nombres)
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_19260\2236453433.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(nombres)
# [Text(0, -1.0, 'preg'),
#  Text(0, 0.0, 'plas'),
#  Text(0, 1.0, 'pres'),
#  Text(0, 2.0, 'skin'),
#  Text(0, 3.0, 'test'),
#  Text(0, 4.0, 'mass'),
#  Text(0, 5.0, 'pedi'),
#  Text(0, 6.0, 'age'),
#  Text(0, 7.0, 'class'),
#  Text(0, 8.0, ''),
#  Text(0, 9.0, '')]

# %%
# %matplotlib inline
correlation = data.corr()
plt.figure(figsize = (10, 10))
ax = sns.heatmap(correlation, vmax=1, square=True, annot=True, cmap='viridis')
plt.title('Matriz de correlación')
plt.show()

# %%
#  Matriz de dispersión
# %matplotlib inline
from pandas.plotting import scatter_matrix
plt.rcParams["figure.figsize"] = (20,15)
scatter_matrix(data)
import pandas as pd

# %%
sns.pairplot(data)
